# %% [markdown]
# # Data Pipeline

# %%
import pandas as pd
import numpy as np

from CCI_Spain.features import datamaker, datamanagement, datamerge, indexmaker, descriptiveanalysis, globalspatialautocorrelation, localspatialautocorrelation, linearmodel, gwrmodel

# %%
VARIABLE_TO_PREDICT =  "CCI"
VARIABLE_TO_DROP = []
AREA_TO_PREDICT = "Spain" # "Spain" # "Iberian Pensinula"

# %%
AREA_TO_PREDICT_dict = {
    "Andalusia": "01", 
    "Aragon": "02",
    "Asturias": "03", 
    "Balearic Islands": "04",
    "Canarias": "05", 
    "Cantabria": "06",
    "Castile and Leon": "07", 
    "Castille-La Mancha": "08",
    "Catalonia": "09", 
    "Valencia": "10",
    "Extremadura": "11", 
    "Galicia": "12",
    "Madrid": "13", 
    "Murcia": "14",
    "Navarre": "15", 
    "Basque Country": "16",
    "La Rioja": "17",
    "Ceuta": "18",
    "Melilla": "19",
    "Minor Plazas de Soberanía": "20",
    }

# %% [markdown]
# ## 00. Data Acquisition

# %%
datamaker.DataMaker()

# %% [markdown]
# ## 01. Data Management

# %%
datamanagement.DataManagement()

# %% [markdown]
# ## 02. Data Merge & (Geocoding)

# %%
datamerge.DataMerge()

# %% [markdown]
# ## 03. Index

# %%
indexmaker.IndexMaker()

# %% [markdown]
# ## 04. Descriptive Analysis

# %%
descriptiveanalysis.DescriptiveAnalysis(AREA_TO_PREDICT)

# %% [markdown]
# ## 05. Global Spatial Autocorrelation

# %%
globalspatialautocorrelation.GlobalSpatialAutocorrelation(VARIABLE_TO_PREDICT, VARIABLE_TO_DROP, AREA_TO_PREDICT)

# %% [markdown]
# ## 06. Local Spatial Autocorrelation

# %%
localspatialautocorrelation.LocalSpatialAutocorrelation(VARIABLE_TO_PREDICT, VARIABLE_TO_DROP, AREA_TO_PREDICT)

# %% [markdown]
# ## 07. Linear Regression Model

# %%
linearmodel.LinearModel(VARIABLE_TO_PREDICT, VARIABLE_TO_DROP, AREA_TO_PREDICT)

# %% [markdown]
# ## 08. GWR Model

# %%
gwrmodel.GWRModel(VARIABLE_TO_PREDICT, VARIABLE_TO_DROP, AREA_TO_PREDICT)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f11c3f49-2b5e-4e69-9186-d202c2d21fb7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
